# %% [markdown]
# <a href="https://colab.research.google.com/github/IbrahimHammed/DataAnalysis/blob/main/DataAnalysis_001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **This is our first attempt at using Python Programming Language to analyse data of different format.**

# %%
# Import relevant libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
# this section indicates the source of our data
# Loading CSV file
filePathCSV = "https://github.com/IbrahimHammed/DataAnalysis/blob/main/recs2015_public_v4.csv?raw=true"

# %%
# This section connects to the file and ingests its data into a dataframe
dfCSV = pd.read_csv(filePathCSV)

# %%
# Preview the dataframe
dfCSV.head()
# Out:
#    DOEID  REGIONC  DIVISION METROMICRO UATYP10  TYPEHUQ  ZTYPEHUQ  CELLAR  \
# 0  10001        4        10      METRO       U        2         0       0
# 1  10002        3         7       NONE       R        2         0       0
# 2  10003        3         6      METRO       U        2         0       1
# 3  10004        2         4      MICRO       C        2         0       1
# 4  10005        1         2      METRO       U        2         0       1
#
#    ZCELLAR  BASEFIN  ...  ZELAMOUNT  NGXBTU  PERIODNG  ZNGAMOUNT  FOXBTU  \
# 0        0       -2  ...          0  103.32         1          0  137.45
# 1        0       -2  ...          1     NaN        -2         -2  137.45
# 2        0        1  ...          0  100.14         1          0  137.45
# 3        0        1  ...          0     NaN        -2         -2  137.45
# 4        0        0  ...          0  102.83         1          0  137.45
#
#    PERIODFO  ZFOAMOUNT  LPXBTU  PERIODLP  ZLPAMOUNT
# ...

# %%
dfCSV.shape
# Out:
# (5686, 759)

# %%
# this section indicates the source of our data
# Loading EXCEL file
filePathXLS = "https://github.com/IbrahimHammed/DataAnalysis/blob/main/Vrinda%20Store%20Data%20Analysis.xlsx?raw=true"
dfXLS = pd.read_excel(filePathXLS)

# %%
dfXLS.shape
# Out:
# (31047, 18)

# %%
dfXLS.head()
# Out:
#               Order ID  Cust ID Gender  Age Age Group       Date Month  \
# 0  171-1029312-3038738  1029312  Women   44    Adults 2022-12-04   Dec
# 1  405-2183842-2225946  2183842  Women   29  Teenager 2022-12-04   Dec
# 2  171-1641533-8921966  1641533  Women   67    Senior 2022-12-04   Dec
# 3  404-7490807-6300351  7490807  Women   20  Teenager 2022-12-04   Dec
# 4  403-9293516-4577154  9293516  Women   62    Senior 2022-12-04   Dec
#
#       Status Channel                       SKU Category Size  Qty currency  \
# 0  Delivered   Myntra  JNE1233-BLUE-KR-031-XXL    kurta  XXL    1      INR
# 1  Delivered     Ajio           SET414-KR-NP-L      Set    L    1      INR
# 2  Delivered   Myntra           SET261-KR-PP-S      Set    S    1      INR
# 3  Delivered   Amazon           SET110-KR-PP-M      Set    M    1      INR
# 4  Delivered   Myntra         JNE2294-KR-A-XXL    kurta  XXL    1      INR
#
#    Amount  ship-city   ship-state  ship-postal-code
# ...

# %%
dfXLS.sample(15)
# Out:
#                   Order ID  Cust ID Gender  Age Age Group       Date Month  \
# 22767  408-2328686-2640352  2328686  Women   27  Teenager 2022-11-06   Nov
# 28188  408-7892412-9026763  7892412  Women   55    Senior 2022-04-06   Apr
# 3474   403-2512276-6163521  2512276    Men   20  Teenager 2022-09-04   Sep
# 5535   406-8246466-5023547  8246466  Women   35    Adults 2022-06-04   Jun
# 5924   171-8209261-6658731  8209261    Men   60    Senior 2022-06-04   Jun
# 21772  403-1332699-6029966  1332699  Women   71    Senior 2022-12-06   Dec
# 17965  404-9752786-9818712  9752786  Women   28  Teenager 2022-04-05   Apr
# 23271  406-2828389-6539529  2828389    Men   19  Teenager 2022-10-06   Oct
# 6040   407-1696530-0321103  1696530  Women   41    Adults 2022-06-04   Jun
# 3642   171-2513441-8744316  2513441  Women   23  Teenager 2022-09-04   Sep
# 14093  407-6328125-4170745  6328125    Men   29  Teenager 2022-08-05   Aug
# ...

# %%
# JSON file source: Javascript Object Notation
filePathJSON = "https://github.com/IbrahimHammed/DataAnalysis/blob/main/file2.json?raw=true"
dfJSON = pd.read_json(filePathJSON)

# %%
dfJSON.shape
# Out:
# (550, 4)

# %%
dfJSON.head()
# Out:
#    results_found  results_start  results_shown  \
# 0        1263908             21             20
# 1        1263908             21             20
# 2        1263908             21             20
# 3        1263908             21             20
# 4        1263908             21             20
#
#                                          restaurants
# 0  [{'restaurant': {'R': {'res_id': 16668008}, 'a...
# 1  [{'restaurant': {'R': {'res_id': 16668008}, 'a...
# 2  [{'restaurant': {'R': {'res_id': 16668008}, 'a...
# 3  [{'restaurant': {'R': {'res_id': 16668008}, 'a...
# 4  [{'restaurant': {'R': {'res_id': 16668008}, 'a...

# %%
# PARQUET File demo
filePathParquet = "https://github.com/IbrahimHammed/DataAnalysis/blob/main/daily_sales_items_top105.parquet?raw=true"
dfParquet = pd.read_parquet(filePathParquet)

# %%
dfParquet.shape
# Out:
# (2038050, 9)

# %%
dfParquet.head()
# Out:
#                                 id        item_id    dept_id   cat_id  \
# 7    HOBBIES_1_008_CA_1_evaluation  HOBBIES_1_008  HOBBIES_1  HOBBIES
# 14   HOBBIES_1_015_CA_1_evaluation  HOBBIES_1_015  HOBBIES_1  HOBBIES
# 47   HOBBIES_1_048_CA_1_evaluation  HOBBIES_1_048  HOBBIES_1  HOBBIES
# 98   HOBBIES_1_103_CA_1_evaluation  HOBBIES_1_103  HOBBIES_1  HOBBIES
# 173  HOBBIES_1_178_CA_1_evaluation  HOBBIES_1_178  HOBBIES_1  HOBBIES
#
#     store_id state_id    d  value       date
# 7       CA_1       CA  489     12 2012-05-31
# 14      CA_1       CA  489     11 2012-05-31
# 47      CA_1       CA  489      0 2012-05-31
# 98      CA_1       CA  489      2 2012-05-31
# 173     CA_1       CA  489      3 2012-05-31

# %%
# Data Type: String, Int16, Int32, Int64, Float, Boolean

# %%
# Web Page
url = "https://www.bbc.com/sport/football/tables"
tables = pd.read_html(url)

# %%
len(tables)
# Out:
# 1

# %%
tables[0]
# Out:
#     Position                     Team  Played  Won  Drawn  Lost  Goals For  \
# 0          1                Liverpool      10    8      1     1         19
# 1          2          Manchester City      10    7      2     1         21
# 2          3        Nottingham Forest      10    5      4     1         14
# 3          4                  Chelsea      10    5      3     2         20
# 4          5                  Arsenal      10    5      3     2         17
# 5          6              Aston Villa      10    5      3     2         17
# 6          7        Tottenham Hotspur      10    5      1     4         22
# 7          8   Brighton & Hove Albion      10    4      4     2         17
# 8          9                   Fulham      10    4      3     3         14
# 9         10          AFC Bournemouth      10    4      3     3         13
# 10        11         Newcastle United      10    4      3     3         10
# ...

# %%
wmLink= "https://raw.githubusercontent.com/IbrahimHammed/DataAnalysis/refs/heads/main/Walmart%20-%20products%20.csv"
filePathParquet = "https://github.com/IbrahimHammed/DataAnalysis/blob/main/daily_sales_items_top105.parquet?raw=true"

# %%
# Ingesting from Google Drive
url = "/content/drive/MyDrive/PythonDatasets/all_stocks_5yr.csv"
dfGoogleDrive = pd.read_csv(url, low_memory=False)

# %%
dfGoogleDrive.shape
# Out:
# (619040, 7)

# %%
dfGoogleDrive.head()
# Out:
#          date   open   high    low  close    volume Name
# 0  2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL
# 1  2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL
# 2  2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL
# 3  2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL
# 4  2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL

# %%
# Chart demo
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Age': [25, 30, 35, 40, 45],
}

# %%
dfChart = pd.DataFrame(data)

# %%
dfChart.shape
# Out:
# (5, 2)

# %%
dfChart.plot(kind='barh', x='Name', y='Age')
plt.show()
