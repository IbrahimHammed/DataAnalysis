# %% [markdown]
# <a href="https://colab.research.google.com/github/IbrahimHammed/DataAnalysis/blob/main/DataAnalysis_004.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
Student = ['Ohoni', 'Patricia', 'Uduak', 'Olaitan', 'AbdSamad', 'Ibrahim']
MatricNo = ['M123', 'M124', '', 'M125', 'M126', '']
MAT101 = [34, 90,56,np.nan,91,np.nan]

# %%
df = pd.DataFrame(data = {'Student': Student, 'MatricNo': MatricNo, 'MAT101': MAT101})

# %%
df
# Out:
#     Student MatricNo  MAT101
# 0     Ohoni     M123    34.0
# 1  Patricia     M124    90.0
# 2     Uduak             56.0
# 3   Olaitan     M125     NaN
# 4  AbdSamad     M126    91.0
# 5   Ibrahim              NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Student   6 non-null      object
#  1   MatricNo  6 non-null      object
#  2   MAT101    4 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 272.0+ bytes

# %%
dfNew = df.dropna()

# %%
dfNew
# Out:
#     Student MatricNo  MAT101
# 0     Ohoni     M123    34.0
# 1  Patricia     M124    90.0
# 2     Uduak             56.0
# 4  AbdSamad     M126    91.0

# %%
df
# Out:
#     Student MatricNo  MAT101
# 0     Ohoni     M123    34.0
# 1  Patricia     M124    90.0
# 2     Uduak             56.0
# 3   Olaitan     M125     NaN
# 4  AbdSamad     M126    91.0
# 5   Ibrahim              NaN
