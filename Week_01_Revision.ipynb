# %% [markdown]
# <a href="https://colab.research.google.com/github/IbrahimHammed/DataAnalysis/blob/main/Week_01_Revision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import relevant libraries
import pandas as pd

# %%
# Reading from Webpages
url = "https://en.wikipedia.org/wiki/World_Bank"

# %%
dfWeb = pd.read_html(url)

# %%
len(dfWeb)
# Out:
# 14

# %%
dfWeb[0]
# Out:
#                                              0  \
# 0  The World Bank building in Washington, D.C.
# 1                                  Established
# 2                                         Type
# 3                                 Legal status
# 4                                 Headquarters
# 5                                   Membership
# 6                                   Key people
# 7                          Parent organization
# 8                                        Staff
# 9                                      Website
#
#                                                    1
# 0        The World Bank building in Washington, D.C.
# 1                        July 7, 1944 (80 years ago)
# 2                International financial institution
# 3                                             Treaty
# 4        1818 H Street, NW Washington, D.C., U.S.[1]
# 5     189 countries (IBRD)[2] 174 countries (IDA)[2]
# 6  Ajay Banga (President)[3]Axel van Trotsenburg ...
# ...

# %%
dfWeb[1]
# Out:
#                              Name         Dates                  Nationality  \
# 0                    Eugene Meyer     1946–1946                United States
# 1                  John J. McCloy     1947–1949                United States
# 2            Eugene R. Black, Sr.     1949–1963                United States
# 3                    George Woods     1963–1968                United States
# 4                 Robert McNamara     1968–1981                United States
# 5                Alden W. Clausen     1981–1986                United States
# 6                  Barber Conable     1986–1991                United States
# 7                Lewis T. Preston     1991–1995                United States
# 8                James Wolfensohn     1995–2005  United States and Australia
# 9                  Paul Wolfowitz     2005–2007                United States
# 10                Robert Zoellick     2007–2012                United States
# ...

# %%
dfWeb[2]
# Out:
#                            Name         Dates               Nationality
# 0             Hollis B. Chenery     1972–1982             United States
# 1           Anne Osborn Krueger     1982–1986             United States
# 2               Stanley Fischer     1988–1990  United States and Israel
# 3              Lawrence Summers     1991–1993             United States
# 4                 Michael Bruno     1993–1996                    Israel
# 5            Joseph E. Stiglitz     1997–2000             United States
# 6                Nicholas Stern     2000–2003            United Kingdom
# 7          François Bourguignon     2003–2007                    France
# 8               Justin Yifu Lin     2008–2012                     China
# 9                  Kaushik Basu     2012–2016                     India
# 10                   Paul Romer     2016–2018             United States
# 11    Shanta Devarajan (Acting)     2018–2018             United States
# ...

# %%
# Export the data to MS excel
dfWeb[2].to_excel("/content/drive/MyDrive/Colab Notebooks/Result.xlsx")

# %%
# Reading from MS Excel File
xlsFilePath = "/content/drive/MyDrive/Budapest Datasets/Task1/Input/FIRST-Man days and Costs by project BRICK4 - 2023-12.xlsx"

# %%
dfXLS = pd.read_excel(xlsFilePath)
dfXLS.head()
# Out:
#     Unnamed: 0              Unnamed: 1              Unnamed: 2  \
# 0  Base Entity  Management Center Type             MCT Meaning
# 1   ARU0100440                     CRU  Clinical Research Unit
# 2   ARU0100440                     CRU  Clinical Research Unit
# 3   ARU0100440                     CRU  Clinical Research Unit
# 4   ARU0100440                     CRU  Clinical Research Unit
#
#           Unnamed: 3        Unnamed: 4    Unnamed: 5 Unnamed: 6  \
# 0  Management Center        MC Meaning  Legal Entity        NAT
# 1              ARU01  ARGENTINA RD AFF         00440        100
# 2              ARU01  ARGENTINA RD AFF         00440        100
# 3              ARU01  ARGENTINA RD AFF         00440        100
# 4              ARU01  ARGENTINA RD AFF         00440        100
#
#                   Unnamed: 7            Unnamed: 8  Unnamed: 9  ...  \
# 0           NAT Code Meaning         Project owner  Flag Scope  ...
# ...

# %%
# Reading from CSV file
csvFilePath = "/content/drive/MyDrive/Analytics Demo Data/SocialNetworkAds.csv"

# %%
dfCSV = pd.read_csv(csvFilePath)
dfCSV.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
# Reading from .TXT file
textFilePath = "/content/drive/MyDrive/Budapest Datasets/FlattenedBricks.txt"

# %%
dfTXT = pd.read_csv(textFilePath, sep="\t")
dfTXT.head()
# Out:
# <ipython-input-15-56338f88db6f>:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfTXT = pd.read_csv(textFilePath, sep="\t")
#   FIRST_TIME FIRST_ENTITY               FIRST_MC_TYPE FIRST_MC FIRST_LE  \
# 0   2023-DEC   ARU0100440  CRU-Clinical Research Unit    ARU01    00440
# 1   2023-DEC   ARU0100440  CRU-Clinical Research Unit    ARU01    00440
# 2   2023-DEC   ARU0100440  CRU-Clinical Research Unit    ARU01    00440
# 3   2023-DEC   ARU0100440  CRU-Clinical Research Unit    ARU01    00440
# 4   2023-DEC   ARU0100440  CRU-Clinical Research Unit    ARU01    00440
#
#                        FIRST_NAT   FIRST_PROJECT_OWNER        FIRST_LC  \
# 0  100-Research Clinical Studies             Neurology  Argentine Peso
# 1  100-Research Clinical Studies  Rare Blood Disorders  Argentine Peso
# 2  100-Research Clinical Studies         Rare Diseases  Argentine Peso
# ...

# %%
# Reading from PARQUET file
parquetFilePath = "https://github.com/IbrahimHammed/DataAnalysis/blob/main/daily_sales_items_top105.parquet?raw=true"

# %%
dfPARQUET = pd.read_parquet(parquetFilePath)
dfPARQUET.head()
# Out:
#                                 id        item_id    dept_id   cat_id  \
# 7    HOBBIES_1_008_CA_1_evaluation  HOBBIES_1_008  HOBBIES_1  HOBBIES
# 14   HOBBIES_1_015_CA_1_evaluation  HOBBIES_1_015  HOBBIES_1  HOBBIES
# 47   HOBBIES_1_048_CA_1_evaluation  HOBBIES_1_048  HOBBIES_1  HOBBIES
# 98   HOBBIES_1_103_CA_1_evaluation  HOBBIES_1_103  HOBBIES_1  HOBBIES
# 173  HOBBIES_1_178_CA_1_evaluation  HOBBIES_1_178  HOBBIES_1  HOBBIES
#
#     store_id state_id    d  value       date
# 7       CA_1       CA  489     12 2012-05-31
# 14      CA_1       CA  489     11 2012-05-31
# 47      CA_1       CA  489      0 2012-05-31
# 98      CA_1       CA  489      2 2012-05-31
# 173     CA_1       CA  489      3 2012-05-31

# %%
# Reading from JSON file
jsonFilePath = "https://github.com/IbrahimHammed/DataAnalysis/blob/main/file2.json?raw=true"

# %%
dfJSON = pd.read_json(jsonFilePath)
dfJSON.head()
# Out:
#    results_found  results_start  results_shown  \
# 0        1263908             21             20
# 1        1263908             21             20
# 2        1263908             21             20
# 3        1263908             21             20
# 4        1263908             21             20
#
#                                          restaurants
# 0  [{'restaurant': {'R': {'res_id': 16668008}, 'a...
# 1  [{'restaurant': {'R': {'res_id': 16668008}, 'a...
# 2  [{'restaurant': {'R': {'res_id': 16668008}, 'a...
# 3  [{'restaurant': {'R': {'res_id': 16668008}, 'a...
# 4  [{'restaurant': {'R': {'res_id': 16668008}, 'a...

# %%
# Reading from API
apiURL = ""

# %%
# Optimization techniques for loading data

# %%
# Choose relevant columns

# %%
# Reading from .TXT file
textFilePath = "/content/drive/MyDrive/Budapest Datasets/FlattenedBricks.txt"

desiredColumns = ['FIRST_TIME','FIRST_ENTITY','FIRST_MC_TYPE','FIRST_MC',	'FIRST_LE',	'FIRST_NAT']

dfTEXT = pd.read_csv(textFilePath, sep="\t", usecols=desiredColumns)
dfTEXT.head()
# Out:
#   FIRST_TIME FIRST_ENTITY               FIRST_MC_TYPE FIRST_MC FIRST_LE  \
# 0   2023-DEC   ARU0100440  CRU-Clinical Research Unit    ARU01    00440
# 1   2023-DEC   ARU0100440  CRU-Clinical Research Unit    ARU01    00440
# 2   2023-DEC   ARU0100440  CRU-Clinical Research Unit    ARU01    00440
# 3   2023-DEC   ARU0100440  CRU-Clinical Research Unit    ARU01    00440
# 4   2023-DEC   ARU0100440  CRU-Clinical Research Unit    ARU01    00440
#
#                        FIRST_NAT
# 0  100-Research Clinical Studies
# 1  100-Research Clinical Studies
# 2  100-Research Clinical Studies
# 3  100-Research Clinical Studies
# 4  100-Research Clinical Studies

# %%
# Choose relevant rows
textFilePath = "/content/drive/MyDrive/Budapest Datasets/FlattenedBricks.txt"
dfTEXT = pd.read_csv(textFilePath, sep="\t", nrows=100)
dfTEXT.head()
# Out:
#   FIRST_TIME FIRST_ENTITY               FIRST_MC_TYPE FIRST_MC FIRST_LE  \
# 0   2023-DEC   ARU0100440  CRU-Clinical Research Unit    ARU01    00440
# 1   2023-DEC   ARU0100440  CRU-Clinical Research Unit    ARU01    00440
# 2   2023-DEC   ARU0100440  CRU-Clinical Research Unit    ARU01    00440
# 3   2023-DEC   ARU0100440  CRU-Clinical Research Unit    ARU01    00440
# 4   2023-DEC   ARU0100440  CRU-Clinical Research Unit    ARU01    00440
#
#                        FIRST_NAT   FIRST_PROJECT_OWNER        FIRST_LC  \
# 0  100-Research Clinical Studies             Neurology  Argentine Peso
# 1  100-Research Clinical Studies  Rare Blood Disorders  Argentine Peso
# 2  100-Research Clinical Studies         Rare Diseases  Argentine Peso
# 3  100-Research Clinical Studies         Rare Diseases  Argentine Peso
# 4  100-Research Clinical Studies         Rare Diseases  Argentine Peso
#
#   FIRST_DEPARTMENT FIRST_INDICATOR FIRST_PROJECT_TYPE  \
# ...

# %%
# Reading from .TXT file
textFilePath = "/content/drive/MyDrive/Budapest Datasets/FlattenedBricks.txt"

desiredColumns = ['FIRST_TIME','FIRST_ENTITY','FIRST_MC_TYPE','FIRST_MC',	'FIRST_LE',	'FIRST_NAT']

dfTEXT = pd.read_csv(textFilePath, sep="\t", usecols=desiredColumns, nrows=100)
dfTEXT.head()
# Out:
#   FIRST_TIME FIRST_ENTITY               FIRST_MC_TYPE FIRST_MC FIRST_LE  \
# 0   2023-DEC   ARU0100440  CRU-Clinical Research Unit    ARU01    00440
# 1   2023-DEC   ARU0100440  CRU-Clinical Research Unit    ARU01    00440
# 2   2023-DEC   ARU0100440  CRU-Clinical Research Unit    ARU01    00440
# 3   2023-DEC   ARU0100440  CRU-Clinical Research Unit    ARU01    00440
# 4   2023-DEC   ARU0100440  CRU-Clinical Research Unit    ARU01    00440
#
#                        FIRST_NAT
# 0  100-Research Clinical Studies
# 1  100-Research Clinical Studies
# 2  100-Research Clinical Studies
# 3  100-Research Clinical Studies
# 4  100-Research Clinical Studies

# %%
# Adjust data types

# %%
dfTEXT.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   FIRST_TIME     100 non-null    object
#  1   FIRST_ENTITY   100 non-null    object
#  2   FIRST_MC_TYPE  100 non-null    object
#  3   FIRST_MC       100 non-null    object
#  4   FIRST_LE       100 non-null    object
#  5   FIRST_NAT      100 non-null    object
# dtypes: object(6)
# memory usage: 4.8+ KB

# %%
dfTEXT['FIRST_TIME'] = pd.to_datetime(dfTEXT['FIRST_TIME'])
dfTEXT['FIRST_ENTITY'] = dfTEXT['FIRST_ENTITY'].astype('string')
dfTEXT['FIRST_MC_TYPE'] = dfTEXT['FIRST_MC_TYPE'].astype('string')
dfTEXT['FIRST_MC'] = dfTEXT['FIRST_MC'].astype('string')
dfTEXT['FIRST_LE'] = dfTEXT['FIRST_LE'].astype('string')
dfTEXT['FIRST_NAT'] = dfTEXT['FIRST_NAT'].astype('string')

# %%
dfTEXT.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   FIRST_TIME     100 non-null    datetime64[ns]
#  1   FIRST_ENTITY   100 non-null    string
#  2   FIRST_MC_TYPE  100 non-null    string
#  3   FIRST_MC       100 non-null    string
#  4   FIRST_LE       100 non-null    string
#  5   FIRST_NAT      100 non-null    string
# dtypes: datetime64[ns](1), string(5)
# memory usage: 4.8 KB

# %%
# Profiling a Dataframe
# Get number of records and columns
dfXLS.shape
# Out:
# (57107, 48)

# %%
dfXLS.shape[0]
# Out:
# 57107

# %%
dfXLS.shape[1]
# Out:
# 48

# %%
# Get column names

# %%
dfXLS.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23', 'Time Spent H',
#        'Time spent MD\n(Time spent H/8)', 'Full costs LC',
#        'Full Direct cost LC', 'Full Internal cost LC',
#        'Support Internal cost LC', 'Direct Internal cost LC',
#        'Full External cost LC', 'Sample cost LC', 'Clinical cost LC',
#        'Partnership cost LC', 'Contract cost LC', 'Adjustment LC',
#        'Full costs GC', 'Full Internal cost GC', 'Direct Internal cost GC',
#        'Support Internal cost GC', 'Full Direct cost GC',
#        'Full External cost GC', 'Contract cost GC', 'Sample cost GC',
# ...

# %%
# Get cloumn names and data types
dfCSV.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User ID          400 non-null    int64
#  1   Gender           400 non-null    object
#  2   Age              400 non-null    int64
#  3   EstimatedSalary  400 non-null    int64
#  4   Purchased        400 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 15.8+ KB

# %%
# check the first n records
dfCSV.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
dfCSV.head(3)
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0

# %%
# Check the last n records
dfCSV.tail(3)
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1

# %%
# Get n sample records
dfCSV.sample(3)
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 105  15801658    Male   21            72000          0
# 191  15662067  Female   19            26000          0
# 195  15667742    Male   34            43000          0

# %%
# Get memory consumed of the dataframe
MB = 1024 * 1024
dfCSV.memory_usage(deep=True).sum() / MB
# Out:
# 0.03598785400390625

# %%
# Get memory consumed of the dataframe
MB = 1024 * 1024
dfXLS.memory_usage(deep=True).sum() / MB
# Out:
# 126.65471458435059

# %%
# Get memory consumed of the dataframe
MB = 1024 * 1024
dfTEXT.memory_usage(deep=True).sum() / MB
# Out:
# 0.03423595428466797

# %%
dfCSV.head(10)
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0
# 5  15728773    Male   27            58000          0
# 6  15598044  Female   27            84000          0
# 7  15694829  Female   32           150000          1
# 8  15600575    Male   25            33000          0
# 9  15727311  Female   35            65000          0

# %%
# Get the n largest values based on a given column
dfCSV.nlargest(10, 'EstimatedSalary')
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 7    15694829  Female   32           150000          1
# 211  15735878    Male   52           150000          1
# 103  15675949  Female   33           149000          1
# 240  15701537    Male   42           149000          1
# 168  15789815    Male   29           148000          1
# 230  15794253  Female   35           147000          1
# 245  15722061  Female   51           146000          1
# 253  15584320  Female   37           146000          1
# 222  15694879    Male   37           144000          1
# 261  15680587    Male   36           144000          1

# %%
# Get the n smallest values based on a given column
dfCSV.nsmallest(10, 'EstimatedSalary')
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 43   15792008    Male   30            15000          0
# 92   15809823    Male   26            15000          0
# 150  15679651  Female   26            15000          0
# 155  15610140  Female   31            15000          0
# 32   15573452  Female   21            16000          0
# 180  15685576    Male   26            16000          0
# 40   15764419  Female   27            17000          0
# 79   15655123  Female   26            17000          0
# 128  15722758    Male   30            17000          0
# 13   15704987    Male   32            18000          0

# %%
# Get unique values in a text column
dfCSV["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
dfCSV["Age"].unique()
# Out:
# array([19, 35, 26, 27, 32, 25, 20, 18, 29, 47, 45, 46, 48, 49, 31, 21, 28,
#        33, 30, 23, 24, 22, 59, 34, 39, 38, 37, 42, 40, 36, 41, 58, 55, 52,
#        60, 56, 53, 50, 51, 57, 44, 43, 54])

# %%
dfCSV["Purchased"].unique()
# Out:
# array([0, 1])

# %%
# Get the sum of all values in a numeric column
total = dfCSV["EstimatedSalary"].sum()
print(f"Total Salary is: NGN{total:,.4f}")
# Out:
# Total Salary is: NGN27,897,000.0000

# %%
# Get the count of all values in a numeric column
dfCSV["EstimatedSalary"].count()
# Out:
# 400

# %%
# Get the maximum value in a numeric column
dfCSV["EstimatedSalary"].max()
# Out:
# 150000

# %%
# Get the minimum value in a numeric column
dfCSV["EstimatedSalary"].min()
# Out:
# 15000

# %%
# Get the average value of a numeric column
dfCSV["EstimatedSalary"].mean()
# Out:
# 69742.5

# %%
# Get the median value of a numeric column
dfCSV["EstimatedSalary"].median()
# Out:
# 70000.0

# %%
# Get the std value of a numeric column
dfCSV["EstimatedSalary"].std()
# Out:
# 34096.960282424785

# %%
# Get the correlation matrix of a numeric columns
dfCorrelation = dfCSV[['Age', 'EstimatedSalary']]
dfCorrelation.head()
# Out:
#    Age  EstimatedSalary
# 0   19            19000
# 1   35            20000
# 2   26            43000
# 3   27            57000
# 4   19            76000

# %%
dfCorrelation.corr()
# Out:
#                       Age  EstimatedSalary
# Age              1.000000         0.155238
# EstimatedSalary  0.155238         1.000000

# %%
# Get the correlation of column with another
#x = pd.Series(dfCSV['Purchased'])
#y = pd.Series(dfCSV[['EstimatedSalary']])

# %%
# Producing a new column from existing one
dfCSV.head(3)
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0

# %%
dfCSV["NewSalary"] = dfCSV["EstimatedSalary"] * 1.14

# %%
dfCSV.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased  NewSalary
# 0  15624510    Male   19            19000          0    21660.0
# 1  15810944    Male   35            20000          0    22800.0
# 2  15668575  Female   26            43000          0    49020.0
# 3  15603246  Female   27            57000          0    64980.0
# 4  15804002    Male   19            76000          0    86640.0

# %%
PurchaseDate, Cost, UsefulLifetime, "Depreciation", "CumDep", "Age", "NBV"

# %%
# Assignment
# Create a folder within your Google Drive name DataAnalytics
# Get and upload files of formats : .xlsx, .txt, .csv, json, .parquet
# Produce python code to connect to the files to achieve the following:
# 1. Show the number of rows and columns
# 2. Show the maximum and minimum values in any numeric column
# 3. Show the memory space utilised by the loaded data in each of the above cases
