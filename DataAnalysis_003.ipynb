# %% [markdown]
# <a href="https://colab.research.google.com/github/IbrahimHammed/DataAnalysis/blob/main/DataAnalysis_003.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
filePath = "https://github.com/IbrahimHammed/DataAnalysis/blob/main/Vrinda%20Store%20Data%20Analysis.xlsx?raw=true"

# %%
dfRaw = pd.read_excel(filePath)

# %%
dfRaw.shape
# Out:
# (31047, 18)

# %%
dfRaw.head(3)
# Out:
#               Order ID  Cust ID Gender  Age Age Group       Date Month  \
# 0  171-1029312-3038738  1029312  Women   44    Adults 2022-12-04   Dec
# 1  405-2183842-2225946  2183842  Women   29  Teenager 2022-12-04   Dec
# 2  171-1641533-8921966  1641533  Women   67    Senior 2022-12-04   Dec
#
#       Status Channel                       SKU Category Size  Qty currency  \
# 0  Delivered   Myntra  JNE1233-BLUE-KR-031-XXL    kurta  XXL    1      INR
# 1  Delivered     Ajio           SET414-KR-NP-L      Set    L    1      INR
# 2  Delivered   Myntra           SET261-KR-PP-S      Set    S    1      INR
#
#    Amount ship-city   ship-state  ship-postal-code
# 0     376    MOHALI       PUNJAB            140301
# 1    1449  GURUGRAM      HARYANA            122002
# 2     453   KOLKATA  WEST BENGAL            700029

# %%
dfRaw.memory_usage().sum()
# Out:
# 4470896

# %%
dfStreamline1 = pd.read_excel(filePath, usecols=["Order ID", "Cust ID", "Gender", "Age", "Age Group", "Date", "Category", "Size", "Qty", "Amount"])

# %%
dfStreamline1.shape
# Out:
# (31047, 10)

# %%
dfStreamline1.head()
# Out:
#               Order ID  Cust ID Gender  Age Age Group       Date Category  \
# 0  171-1029312-3038738  1029312  Women   44    Adults 2022-12-04    kurta
# 1  405-2183842-2225946  2183842  Women   29  Teenager 2022-12-04      Set
# 2  171-1641533-8921966  1641533  Women   67    Senior 2022-12-04      Set
# 3  404-7490807-6300351  7490807  Women   20  Teenager 2022-12-04      Set
# 4  403-9293516-4577154  9293516  Women   62    Senior 2022-12-04    kurta
#
#   Size  Qty  Amount
# 0  XXL    1     376
# 1    L    1    1449
# 2    S    1     453
# 3    M    1     729
# 4  XXL    1     544

# %%
dfStreamline1.memory_usage().sum()
# Out:
# 2483888

# %%
dfStreamline2 = pd.read_excel(filePath, nrows=15000)

# %%
dfStreamline2.head()
# Out:
#               Order ID  Cust ID Gender  Age Age Group       Date Month  \
# 0  171-1029312-3038738  1029312  Women   44    Adults 2022-12-04   Dec
# 1  405-2183842-2225946  2183842  Women   29  Teenager 2022-12-04   Dec
# 2  171-1641533-8921966  1641533  Women   67    Senior 2022-12-04   Dec
# 3  404-7490807-6300351  7490807  Women   20  Teenager 2022-12-04   Dec
# 4  403-9293516-4577154  9293516  Women   62    Senior 2022-12-04   Dec
#
#       Status Channel                       SKU Category Size  Qty currency  \
# 0  Delivered   Myntra  JNE1233-BLUE-KR-031-XXL    kurta  XXL    1      INR
# 1  Delivered     Ajio           SET414-KR-NP-L      Set    L    1      INR
# 2  Delivered   Myntra           SET261-KR-PP-S      Set    S    1      INR
# 3  Delivered   Amazon           SET110-KR-PP-M      Set    M    1      INR
# 4  Delivered   Myntra         JNE2294-KR-A-XXL    kurta  XXL    1      INR
#
#    Amount  ship-city   ship-state  ship-postal-code
# ...

# %%
dfStreamline2.memory_usage().sum()
# Out:
# 2160128

# %%
dfStreamline3 = pd.read_excel(filePath, nrows=15000, usecols=["Order ID", "Cust ID", "Gender", "Age", "Age Group", "Date", "Category", "Size", "Qty", "Amount"])

# %%
dfStreamline3.head()
# Out:
#               Order ID  Cust ID Gender  Age Age Group       Date Category  \
# 0  171-1029312-3038738  1029312  Women   44    Adults 2022-12-04    kurta
# 1  405-2183842-2225946  2183842  Women   29  Teenager 2022-12-04      Set
# 2  171-1641533-8921966  1641533  Women   67    Senior 2022-12-04      Set
# 3  404-7490807-6300351  7490807  Women   20  Teenager 2022-12-04      Set
# 4  403-9293516-4577154  9293516  Women   62    Senior 2022-12-04    kurta
#
#   Size  Qty  Amount
# 0  XXL    1     376
# 1    L    1    1449
# 2    S    1     453
# 3    M    1     729
# 4  XXL    1     544

# %%
dfStreamline3.memory_usage().sum()
# Out:
# 1200128
